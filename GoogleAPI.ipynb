# %%
import urllib.request
import json
import pandas as pd

# %%
#Google API_Key 
API_Key = 'AIzaSyA5zNwLGCgFjrWT_9_vMfzjznefT9qk0rs'

#Keywords setting. We are going to see all the pizza stores in Manhatten 
ManhattanCoordinates = [-73.96625,40.78343]
Keyword = 'pizza'
radius = 500

# %%
#Python urllib manual : https://docs.python.org/3/library/urllib.request.html
req = urllib.request.Request('https://maps.googleapis.com/maps/api/place/nearbysearch/json?location='+str(ManhattanCoordinates[1])+','+str(ManhattanCoordinates[0])+'&radius='+str(radius)+'&type=restaurant&keyword='+Keyword+'&key='+API_Key)
try: 
    resp = urllib.request.urlopen(req)
    raw = resp.read()
except urllib.error.URLError as e:
    print(e.reason)

# %%
encoding = resp.info().get_content_charset('utf-8')
jdata = json.loads(raw.decode(encoding))
df = pd.DataFrame(jdata['results'])

# %%
# Out:
#                                              geometry  \
# 0   {'location': {'lat': 40.7862328, 'lng': -73.97...
# 1   {'location': {'lat': 40.7845765, 'lng': -73.97...
# 2   {'location': {'lat': 40.78568699999999, 'lng':...
# 3   {'location': {'lat': 40.7858585, 'lng': -73.97...
# 4   {'location': {'lat': 40.7855246, 'lng': -73.97...
# 5   {'location': {'lat': 40.7853069, 'lng': -73.97...
# 6   {'location': {'lat': 40.779508, 'lng': -73.960...
# 7   {'location': {'lat': 40.786044, 'lng': -73.972...
# 8   {'location': {'lat': 40.77916999999999, 'lng':...
# 9   {'location': {'lat': 40.78580100000001, 'lng':...
# 10  {'location': {'lat': 40.7877938, 'lng': -73.97...
# 11  {'location': {'lat': 40.7847702, 'lng': -73.97...
# 12  {'location': {'lat': 40.7798397, 'lng': -73.95...
#
#                                                  icon  \
# 0   https://maps.gstatic.com/mapfiles/place_api/ic...
# 1   https://maps.gstatic.com/mapfiles/place_api/ic...
# ...
