# %%
import urllib.request
import json
import pandas as pd
import time

# %%
#Google API_Key 
API_Key = 'AIzaSyA5zNwLGCgFjrWT_9_vMfzjznefT9qk0rs'

#Keywords setting. We are going to see all the pizza stores in Manhattan
#Mnahattan coordinates cover uptown, central park area, midtown, downtown areas
#Format: lon/lat

ManhattanCoordinates = [(-73.941630,40.834389), (-73.962733,40.785769), (-73.983761,40.758388),
                        (-73.996725,40.727308)]
Keyword = 'pizza'
radius = 17000

# %%
def process_api_data(link):
    #Read the data form link
    req = urllib.request.Request(link)
    try: 
        resp = urllib.request.urlopen(req)
        raw = resp.read()
    except urllib.error.URLError as e:
        print(e.reason)
        
    #Decode data into a dataframe
    encoding = resp.info().get_content_charset('utf-8')
    jdata = json.loads(raw.decode(encoding))
    df = pd.DataFrame(jdata['results'])
    
    #Obtain next page token to see the next set of results.
    #If all results fit on one page, then the next page token will not be returned.
    try:
        next_page_token = jdata['next_page_token']
    except KeyError:
        next_page_token = None

    return df, next_page_token

# %%
#Create a request link for Google API with desired parameters
def create_link(Coordinates, radius, Keyword, first_request, next_page_token):
    
    if first_request == True:
        link = 'https://maps.googleapis.com/maps/api/place/nearbysearch/json?location='+ \
                                 str(Coordinates[1])+','+str(Coordinates[0])+ \
                                 '&radius='+str(radius)+'&type=restaurant&keyword='+Keyword+'&key='\
                                 +API_Key
                    
    else:
        link = 'https://maps.googleapis.com/maps/api/place/nearbysearch/json?location='+ \
                                 str(Coordinates[1])+','+str(Coordinates[0])+ \
                                 '&radius='+str(radius)+'&type=restaurant&keyword='+Keyword+'&key='\
                                 +API_Key+ '&pagetoken=' + next_page_token
    return link

# %%
#Combine searches from all pages into a single dataframe

final_df = pd.DataFrame()

for borough in ManhattanCoordinates:
    
    counter = 1
    
    print(borough)
    
    while True:

        print('Processing results page', str(counter))

        if counter == 1:
            first_request = True
            next_page_token = None
        else:
            first_request = False

        link = create_link(borough, radius, Keyword, first_request, next_page_token)
        df, next_page_token = process_api_data(link)
        final_df = final_df.append(df, ignore_index=True)

        #Meaning if there're no more pages in the search
        if next_page_token == None:
            print('Done!')
            break
        
        #Wait for 3 seconds before using API again
        time.sleep(3)

        counter +=1
# Out:
# (-73.94163, 40.834389)
# Processing results page 1
# Processing results page 2
# Processing results page 3
# Done!
# (-73.962733, 40.785769)
# Processing results page 1
# Processing results page 2
# Processing results page 3
# Done!
# (-73.983761, 40.758388)
# Processing results page 1
# Processing results page 2
# Processing results page 3
# Done!
# (-73.996725, 40.727308)
# Processing results page 1
# Processing results page 2
# Processing results page 3
# Done!

# %%
final_df.shape
# Out:
# (240, 13)

# %%
# Extract coordinates from geometry and drop the json format 
final_df = pd.concat([final_df, final_df['geometry'].apply(pd.Series)], axis=1)
final_df = pd.concat([final_df, final_df['location'].apply(pd.Series)], axis=1)
final_df.drop(['geometry','location','viewport'],axis =1, inplace = True)

# %%
#Extract opening hours from json format 
final_df = pd.concat([final_df, final_df['opening_hours'].apply(pd.Series)], axis=1)
final_df.drop(['opening_hours', 'weekday_text'],axis =1, inplace = True)
# Out:
# /Users/ksenia/anaconda/envs/py36/lib/python3.6/site-packages/pandas/core/indexes/api.py:43: RuntimeWarning: '>' not supported between instances of 'int' and 'str', sort order is undefined for incomparable objects
#   union = _union_indexes(indexes)
# /Users/ksenia/anaconda/envs/py36/lib/python3.6/site-packages/pandas/core/indexes/api.py:77: RuntimeWarning: '>' not supported between instances of 'int' and 'str', sort order is undefined for incomparable objects
#   result = result.union(other)

# %%
#Remove duplicated restaurants
final_df = final_df.drop_duplicates('id', keep='first', inplace=False)

# %%
#Create a feature showing if the location is in NYC(Manhattan)
final_df['borough'] = final_df.vicinity.apply(lambda x: 'NYC' if 'York' in x.split()[-1] else 'Not NYC' )

# %%
#Only select listings that are in NYC
final_df = final_df[final_df.borough == 'NYC']

# %%
#Get rid of unecessary column
try:
    final_df.drop(0,axis=1, inplace=True)
except ValueError:
    print('No columns with 0')

# %%
#Reset index to be in ascending order
final_df = final_df.reset_index(drop=True)

# %%
final_df.columns
# Out:
# Index(['icon', 'id', 'name', 'photos', 'place_id', 'price_level', 'rating',
#        'reference', 'scope', 'types', 'vicinity', 'lat', 'lng', 'open_now',
#        'borough'],
#       dtype='object')

# %%
#Change order of columns to be more convenient for further processing and analysis
cols = ['name', 'lat', 'lng', 'vicinity','open_now', 'rating', 'price_level','icon', 'id','photos', 'place_id',
       'reference', 'scope', 'types','borough']

final_df = final_df[cols]

# %%
final_df
# Out:
#                                     name        lat        lng  \
# 0                   Lazzara's Pizza Cafe  40.754012 -73.989521
# 1       42nd Street Restaurant and Pizza  40.761911 -74.000037
# 2                             Lombardi's  40.721570 -73.995637
# 3                       NY Pizza Suprema  40.750185 -73.995280
# 4                         Angelo's Pizza  40.763812 -73.982945
# 5                       Patsy's Pizzeria  40.750266 -73.972093
# 6                                Lunetta  40.736959 -73.984216
# 7       P&M Classic Pizza and Restaurant  40.826154 -73.946575
# 8   Patzeria Perfect Pizza Pasta & Grill  40.759468 -73.986771
# 9         Da Vinci Pizzeria & Restaurant  40.703608 -74.010109
# 10                   La Pizza & La Pasta  40.741993 -73.989936
# 11           Angelo's Coal Oven Pizzeria  40.764892 -73.977975
# 12                          Cheesy Pizza  40.797213 -73.969582
# 13           Bella Vita Brick Oven Pizza  40.765772 -73.978740
# 14                         Steve's Pizza  40.709435 -74.012024
# 15                        Angelo's Pizza  40.758001 -73.966609
# 16                      Patsy's Pizzeria  40.732867 -73.993380
# 17                           Bravo Pizza  40.753221 -73.980700
# 18                      Picasso Pizzeria  40.710385 -74.016469
# 19                               Ribalta  40.733267 -73.991624
# 20                        A-1 Pizza Shop  40.714552 -73.982356
# 21                John's of Times Square  40.758226 -73.988378
#
#                              vicinity open_now  rating  price_level  \
# 0   221 West 38th Street #2, New York    False     4.1          2.0
# 1      647 West 42nd Street, New York    False     3.2          2.0
# 2          32 Spring Street, New York     True     4.1          2.0
# 3            413 8th Avenue, New York     True     4.5          2.0
# 4             1697 Broadway, New York     True     4.0          2.0
# 5            801 2nd Avenue, New York     True     4.1          2.0
# 6            245 3rd Avenue, New York     True     4.1          NaN
# 7     1747 Amsterdam Avenue, New York    False     4.7          1.0
# 8      231 West 46th Street, New York     True     4.2          2.0
# 9           44 Water Street, New York    False     4.4          2.0
# 10  200 5th Avenue, Floor 1, New York     True     4.1          NaN
# 11     117 West 57th Street, New York     True     4.1          2.0
# 12            2640 Broadway, New York     True     4.0          2.0
# 13     158 West 58th Street, New York     True     4.1          2.0
# 14         110 Cedar Street, New York     True     4.1          2.0
# 15          1043 2nd Avenue, New York     True     3.9          2.0
# 16      67 University Place, New York     True     3.9          2.0
# 17       6 East 42nd Street, New York     True     3.8          2.0
# 18     303 South End Avenue, New York    False     4.1          2.0
# 19      48 East 12th Street, New York     True     4.3          2.0
# 20         505 Grand Street, New York      NaN     4.0          1.0
# 21       260 W. 44th Street, New York     True     4.1          2.0
#
#                                                  icon  \
# 0   https://maps.gstatic.com/mapfiles/place_api/ic...
# 1   https://maps.gstatic.com/mapfiles/place_api/ic...
# 2   https://maps.gstatic.com/mapfiles/place_api/ic...
# 3   https://maps.gstatic.com/mapfiles/place_api/ic...
# 4   https://maps.gstatic.com/mapfiles/place_api/ic...
# 5   https://maps.gstatic.com/mapfiles/place_api/ic...
# 6   https://maps.gstatic.com/mapfiles/place_api/ic...
# 7   https://maps.gstatic.com/mapfiles/place_api/ic...
# 8   https://maps.gstatic.com/mapfiles/place_api/ic...
# 9   https://maps.gstatic.com/mapfiles/place_api/ic...
# 10  https://maps.gstatic.com/mapfiles/place_api/ic...
# 11  https://maps.gstatic.com/mapfiles/place_api/ic...
# 12  https://maps.gstatic.com/mapfiles/place_api/ic...
# 13  https://maps.gstatic.com/mapfiles/place_api/ic...
# 14  https://maps.gstatic.com/mapfiles/place_api/ic...
# 15  https://maps.gstatic.com/mapfiles/place_api/ic...
# 16  https://maps.gstatic.com/mapfiles/place_api/ic...
# 17  https://maps.gstatic.com/mapfiles/place_api/ic...
# 18  https://maps.gstatic.com/mapfiles/place_api/ic...
# 19  https://maps.gstatic.com/mapfiles/place_api/ic...
# 20  https://maps.gstatic.com/mapfiles/place_api/ic...
# 21  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                           id  \
# 0   927d63fac1099cbb316e9595f806c842a206fcb4
# 1   100cb54e06ed4d58f7a07824060944d287ad300e
# 2   73973bd1fac905f102ee1afe536594dc42bca5ff
# 3   5ed03945fe2d1238dba9bb50ac5a2d19f5062f4f
# 4   3f54bd0f9c6bb8377f5411ccb6b09ef1d9ce655c
# 5   aa3d4b9a8e076a32bd0f417b5a79a4c2d59f4c64
# 6   2c4eb506e8cc7ad0d3a3b5796258dafb956939b8
# 7   31f44d5c640ad7d4737047373e4cf4dbd957f173
# 8   f846f7d4dfd546c188f700c627e955ce1c633714
# 9   af051f4faa37683461e56b8878a20c39e3a11d02
# 10  a41479925182de72152cede2f15d240f8f547868
# 11  6a57bd1ce82a5ccb9b3b0d58db48f74259f61cb6
# 12  24eab1ec5fbb6ead1345b745e5e0b126da281e4a
# 13  e1e69188576bfc189c36f8ea645697f26497cfa2
# 14  cdfd832581899716747abfc1f67667258fa283a6
# 15  5d19aa1228ad18f44b964bf28b32f732dd3a2823
# 16  771d3e5d7cc44501e625f41bbef2520b5f988e8a
# 17  1eb5bd458241c2808040ba9940e2a5c82c0d538a
# 18  459649f7a5a90a3f313be2c4a19f840d4a459931
# 19  ef430039a66b0d931e5fdb06349e3c4cc147d8cb
# 20  599c4218155be37ccd89c4e3c4414d6b7914025c
# 21  df91ea6f45a91e87bc34513f138d7d8ce4839cca
#
#                                                photos  \
# 0   [{'height': 1360, 'html_attributions': ['<a hr...
# 1   [{'height': 400, 'html_attributions': ['<a hre...
# 2   [{'height': 3024, 'html_attributions': ['<a hr...
# 3   [{'height': 3024, 'html_attributions': ['<a hr...
# 4   [{'height': 1704, 'html_attributions': ['<a hr...
# 5   [{'height': 1836, 'html_attributions': ['<a hr...
# 6   [{'height': 1000, 'html_attributions': ['<a hr...
# 7   [{'height': 1832, 'html_attributions': ['<a hr...
# 8   [{'height': 2268, 'html_attributions': ['<a hr...
# 9   [{'height': 2988, 'html_attributions': ['<a hr...
# 10  [{'height': 4160, 'html_attributions': ['<a hr...
# 11  [{'height': 3024, 'html_attributions': ['<a hr...
# 12  [{'height': 350, 'html_attributions': ['<a hre...
# 13  [{'height': 1000, 'html_attributions': ['<a hr...
# 14  [{'height': 3000, 'html_attributions': ['<a hr...
# 15  [{'height': 667, 'html_attributions': ['<a hre...
# 16  [{'height': 1360, 'html_attributions': ['<a hr...
# 17  [{'height': 1836, 'html_attributions': ['<a hr...
# 18  [{'height': 768, 'html_attributions': ['<a hre...
# 19  [{'height': 2988, 'html_attributions': ['<a hr...
# 20  [{'height': 2048, 'html_attributions': ['<a hr...
# 21  [{'height': 796, 'html_attributions': ['<a hre...
#
#                        place_id  \
# 0   ChIJ_1bEhaxZwokRIqNQV6dunL8
# 1   ChIJnbALD0xYwokRX9Z_ygcuFPw
# 2   ChIJp-cWE4pZwokRmUI8_BIF8dg
# 3   ChIJsS_-2rFZwokRWYvlpNNbjmg
# 4   ChIJCTvSdPhYwokR5PDoOE7VuCc
# 5   ChIJyxltMANZwokRJ6SOzQ1-Mf4
# 6   ChIJ5Q-Ra6BZwokRd1gGerJ74s8
# 7   ChIJqX832Xz2wokRCmDaupc-83M
# 8   ChIJIcJCN1RYwokRHQzLh_iGQwI
# 9   ChIJh3kfNxRawokRvb3F7FlLswk
# 10  ChIJ6RV0FqRZwokR4QupKOKzxsE
# 11  ChIJVTtHRfdYwokRnbMmdpG2Mw0
# 12  ChIJaRoOcyb2wokRUOfG3SZXr9E
# 13  ChIJWzKtFfdYwokR6bvnMrNyKIo
# 14  ChIJ37TJUxdawokRQUvJ1X8oeyo
# 15  ChIJxWLfC-RYwokRdtnQqGZZOxE
# 16  ChIJq3gz6plZwokR1WPh3L5frsc
# 17  ChIJ44UCRgBZwokRPt7jjyziLpY
# 18  ChIJOWVTySJawokRBoW1r7qh-Us
# 19  ChIJybOUCJlZwokRxiXBjbhX-iA
# 20  ChIJE0lIT9VbwokRR55ei5PticM
# 21  ChIJBSESh1RYwokRyHcVnrG7JWo
#
#                                             reference   scope  \
# 0   CmRSAAAAlzfdPqKGrRG7hHnUf96ox6kX7m-uED6OO0z0Oj...  GOOGLE
# 1   CmRSAAAAwbqDtcpr5oWuFb7Anfmcv6mCKM4xslvUhKrPLc...  GOOGLE
# 2   CmRSAAAAO3wXnTPS97edcDWl7s5wz24neY5yzU__TaFRM-...  GOOGLE
# 3   CmRRAAAA_zLKaOKvYHqk1hjvdlhGTu4aNj_ZvFCS633TLV...  GOOGLE
# 4   CmRRAAAAUmmVNBw3VOymbGkeeREC--rcvTsdq8O-6z3HlG...  GOOGLE
# 5   CmRSAAAAenjMOS-NutkH7O9z7J0g70DHvEFmJQIRojrcJs...  GOOGLE
# 6   CmRSAAAAF36q32HYw3w-ZHvtfZVEubsI6_KRt-eGp6_li0...  GOOGLE
# 7   CmRRAAAAs4R77MMUexycq4lI4ndouKQ1KmI35ZU93AYXg2...  GOOGLE
# 8   CmRRAAAAk3byEaoRhTpcIguuc2xGaBEExEBC8l4tThC2Zj...  GOOGLE
# 9   CmRRAAAAKB584tF7Zm0wb5YTD5X3lrVxgfQkGGE4SphM3N...  GOOGLE
# 10  CmRSAAAAQcTUL6j6oC-4inbnjdJNcS859oyz5tC1DznvNb...  GOOGLE
# 11  CmRRAAAAT30GlxcXvckqsMRRj8q7dLAEv0z3718mRI6y9q...  GOOGLE
# 12  CmRSAAAApEqv4bQ5aHPk6A3etJ8f4Q6MNAmi6Jfqce7FSs...  GOOGLE
# 13  CmRSAAAAO76pgH1N8R5EOc3Y0hkMw6d7dhb2XMVQZFJF3w...  GOOGLE
# 14  CmRRAAAAJ5ijmj95TLvVeQVnSl7i5bUaAmYhzDSA8OFsQn...  GOOGLE
# 15  CmRRAAAAYN6X-iQeJs0ekNdpdcz9CKodoljesa4PFneVB2...  GOOGLE
# 16  CmRSAAAAYOYFor3Lhpr9iTD5hKNueT0Picx8Qe_shffpou...  GOOGLE
# 17  CmRSAAAAVUYYw3jzG8p6FmfwXmOiOqb2aJ4KSiW0Vmb8sW...  GOOGLE
# 18  CmRRAAAAw93tk21LWcISyEW9Ld5FRB4uWqZcjYsNIEqKsD...  GOOGLE
# 19  CmRRAAAAzk-pNgsn9Nb6Ej0sk8lgH1s6nc4d4WRh-symMb...  GOOGLE
# 20  CmRSAAAAdXK6TilvJtvn7kq05mJof4go2lwCFTomn7pQEu...  GOOGLE
# 21  CmRRAAAAz6Sj-6JNWnpaREO8Qb-IETXlG8sSryzxCoqoqc...  GOOGLE
#
#                                                 types borough
# 0   [bar, restaurant, food, point_of_interest, est...     NYC
# 1   [meal_takeaway, restaurant, food, store, point...     NYC
# 2   [meal_takeaway, restaurant, food, point_of_int...     NYC
# 3   [restaurant, food, point_of_interest, establis...     NYC
# 4   [restaurant, food, point_of_interest, establis...     NYC
# 5   [bar, restaurant, food, point_of_interest, est...     NYC
# 6   [restaurant, food, point_of_interest, establis...     NYC
# 7   [restaurant, food, point_of_interest, establis...     NYC
# 8   [meal_delivery, meal_takeaway, restaurant, foo...     NYC
# 9   [restaurant, food, point_of_interest, establis...     NYC
# 10  [restaurant, food, point_of_interest, establis...     NYC
# 11  [restaurant, food, point_of_interest, establis...     NYC
# 12  [restaurant, food, point_of_interest, establis...     NYC
# 13  [restaurant, food, point_of_interest, establis...     NYC
# 14  [restaurant, food, point_of_interest, establis...     NYC
# 15  [restaurant, food, point_of_interest, establis...     NYC
# 16  [restaurant, food, point_of_interest, establis...     NYC
# 17  [restaurant, food, point_of_interest, establis...     NYC
# 18  [restaurant, food, point_of_interest, establis...     NYC
# 19  [restaurant, food, point_of_interest, establis...     NYC
# 20  [restaurant, food, point_of_interest, establis...     NYC
# 21  [restaurant, food, point_of_interest, establis...     NYC
